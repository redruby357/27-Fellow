# %%
import pandas as pd

# %%
df= pd.read_csv('db_measurements.csv')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_7096\2161312484.py:1: DtypeWarning: Columns (0: subject_id, 1: air_movement_acceptability, 2: air_movement_preference) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('db_measurements.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  index  record_id  building_id             timestamp  season  \
# 0           0      0          1            1  1995-05-18T00:00:00Z  winter
# 1           1      1          2            1  1995-05-18T00:00:00Z  winter
# 2           2      2          3            1  1995-05-18T00:00:00Z  winter
# 3           3      3          4            1  1995-05-18T00:00:00Z  winter
# 4           4      4          5            1  1995-05-18T00:00:00Z  winter
#
#   subject_id  age  gender  ht  ...  t_out  rh_out  t_out_isd  rh_out_isd  \
# 0       10.0  NaN  female NaN  ...  15.86    99.1  16.295833   86.837514
# 1       14.0  NaN  female NaN  ...  15.86    99.1  16.295833   86.837514
# 2       15.0  NaN  female NaN  ...  15.86    99.1  16.295833   86.837514
# 3       17.0  NaN  female NaN  ...  15.86    99.1  16.295833   86.837514
# 4       21.0  NaN    male NaN  ...  15.86    99.1  16.295833   86.837514
#
#     set   pmv   ppd  pmv_ce  ppd_ce  t_mot_isd
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'record_id', 'building_id', 'timestamp',
#        'season', 'subject_id', 'age', 'gender', 'ht', 'wt', 'ta', 'ta_h',
#        'ta_m', 'ta_l', 'top', 'tr', 'tg', 'tg_h', 'tg_m', 'tg_l', 'rh', 'vel',
#        'vel_h', 'vel_m', 'vel_l', 'met', 'clo', 'activity_10', 'activity_20',
#        'activity_30', 'activity_60', 'thermal_sensation',
#        'thermal_acceptability', 'thermal_preference', 'thermal_comfort',
#        'air_movement_acceptability', 'air_movement_preference',
#        'blind_curtain', 'fan', 'window', 'door', 'heater', 't_out', 'rh_out',
#        't_out_isd', 'rh_out_isd', 'set', 'pmv', 'ppd', 'pmv_ce', 'ppd_ce',
#        't_mot_isd'],
#       dtype='str')

# %%
df.to_excel('db_measurements.xlsx', sheet_name= 'testing', index= False)
